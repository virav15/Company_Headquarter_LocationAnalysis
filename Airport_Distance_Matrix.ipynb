# %%
# Dependencies Libraries 
import csv
import pandas as pd
import requests as req
import json

# %%
#CSV Files
airport_complete = "airports.csv"
airport_data = pd.read_csv(airport_complete, encoding='iso-8859-1')

# %%
#API
gkey = "AIzaSyBSkya72qegWBCDVGTCbuTjAq7JQ4RYsvU"

# %%
airport_data.head()
# Out:
#        id ident           type                                name  \
# 0    6523   00A       heliport                   Total Rf Heliport
# 1  323361  00AA  small_airport                Aero B Ranch Airport
# 2    6524  00AK  small_airport                        Lowell Field
# 3    6525  00AL  small_airport                        Epps Airpark
# 4    6526  00AR         closed  Newport Hospital & Clinic Heliport
#
#    latitude_deg  longitude_deg  elevation_ft continent iso_country iso_region  \
# 0     40.070801     -74.933601          11.0       NaN          US      US-PA
# 1     38.704022    -101.473911        3435.0       NaN          US      US-KS
# 2     59.949200    -151.695999         450.0       NaN          US      US-AK
# 3     34.864799     -86.770302         820.0       NaN          US      US-AL
# 4     35.608700     -91.254898         237.0       NaN          US      US-AR
#
#    municipality scheduled_service gps_code iata_code local_code home_link  \
# ...

# %%
#Cleaning up Airport Data 
major_airport = airport_data.loc[(airport_data["type"] == "large_airport") & (airport_data["iso_country"] == "US")]
major_airport = major_airport.drop(['elevation_ft', 'continent', 'scheduled_service', 'home_link', 'wikipedia_link', 'keywords', 'gps_code', 'iata_code', 'local_code'], axis=1)
major_airport = major_airport.rename(columns={'latitude_deg': 'latitude', 'longitude_deg': 'longitude', 'iso_region':'state', 'municipality':'city', 'name':'airport', 'iso_country':'country'})
major_airport.head()
